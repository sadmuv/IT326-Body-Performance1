# %%
import pandas as pd
# Updated path to match the file location in your environment
df = pd.read_csv("bodyPerformance.csv")

# 2) Print dataset shape (rows, columns)
print("Shape (rows, columns):", df.shape)

# 3) Print columns names
print("\nColumns:")
print(df.columns.tolist())

# 4) Print data types
print("\nData Types:")
print(df.dtypes)

# 5) General info (includes non-null counts)
print("\nInfo:")
df.info()

# 6) Class label + counts لكل كلاس
print("\nClass label counts:")
print(df["class"].value_counts())

# 7) Sample of raw dataset
print("\nSample (first 5 rows):")
print(df.head())
# Out:
# Shape (rows, columns): (13393, 12)
#
# Columns:
# ['age', 'gender', 'height_cm', 'weight_kg', 'body fat_%', 'diastolic', 'systolic', 'gripForce', 'sit and bend forward_cm', 'sit-ups counts', 'broad jump_cm', 'class']
#
# Data Types:
# age                        float64
# gender                      object
# height_cm                  float64
# weight_kg                  float64
# body fat_%                 float64
# diastolic                  float64
# systolic                   float64
# gripForce                  float64
# sit and bend forward_cm    float64
# sit-ups counts             float64
# broad jump_cm              float64
# class                       object
# dtype: object
#
# Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13393 entries, 0 to 13392
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   age                      13393 non-null  float64
# ...
